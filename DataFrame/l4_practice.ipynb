# %% [markdown]
# ### This jupyter notebook contains practical assignments for the lesson "Introduction to DataFrames"
#
# **Author : Umidjon Sattorov. Machine Learning engineer**

# %% [markdown]
# 1. Сначала импортируйте библиотеки pandas и numpy.

# %%
# Your code goes here

# %% [markdown]
# 2. Создайте следующий DataFrame.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Your code goes here

# %% [markdown]
# 3. Верните первые 3 строки DataFrame.

# %%
# Your code goes here

# %% [markdown]
# 4. Верните случайные две строки из DataFrame.

# %%
# Your code goes here

# %% [markdown]
# 5. Верните только имя (name), пол (gender) и количество домашних животных (num_pets) людей.

# %%
# Your code goes here
